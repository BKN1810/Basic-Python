# %% [markdown]
# # Many-to-Many LSTM for Sequence Prediction (with TimeDistributed)
# ## Many-to-Many LSTM for Sequence Prediction (with TimeDistributed)
# ### Many-to-Many LSTM for Sequence Prediction (with TimeDistributed)
# #### Many-to-Many LSTM for Sequence Prediction (with TimeDistributed)

# %% [markdown]
# # ## This examples are to make letter Bold.
#
# <b> This is for Bold.
#
# <br> This is for next line.
# <br>'**Nepal**'
# <br> "**Nepal**"
#
# <br>for underscore use
# '__Underscore__'

# %% [markdown]
# #### for italic
# *this is Nepal*
# <br>_this is Nepal_

# %% [markdown]
# ### 4. Bullets
# <b> 1. Circular Bullet. <br>
#     use adash sign (-)  with a space after it or use ths asterik sign (*) with a space after it. <br>
# <b> 2. Sub Bullet
#     use a tab followed by dash and a space  or use ths asterik sign (*) with a space after it. <br>
#
# - <b> 1. Circular Bullet
# - <b> 2. Sub Bullet
#
#     - <b> 1. Circular Bullet
#     - <b> 2. Sub Bullet

# %% [markdown]
# ### 5. Numbr List
#
# 1. one
# 2. two
# 3. three
#
#     1. apple
#     2. Ball

# %% [markdown]
# ### 6. Mathematical Symbol
# >#### Use dollar sign before and after the mathematicla symbol
#
# 1. $x^2$
# 2. $x_j$
# 3. $\frac{3}{x+1}$
# 4. $\sqrt{x^2 + y^2}$
# 5. $\sqrt{x^2}$
# 6. $\lfloor x/2 \rfloor$
# 7. $\lceil x/2 \rceil$
# 8. $$\frac{\sqrt{\frac{1}{x} + 1}}{a_1 + a_2 + a_3}$$

# %% [markdown]
# ### 7. Indented Quoting
#
# >"This is singla Indent." <br>
#
# >>"**This is Double indent.**"

# %% [markdown]
# ### 8. Line Break
#
# This is a Sentence. <br> This is the example of Line break.

# %% [markdown]
# ### 9. Image insert
# "** You can attach directly image file in Markdown cell. Drag and Drop the image file to the Markdown cell to attached to the notebook.![pic%20%2811%29.jpg](attachment:pic%20%2811%29.jpg)

# %% [markdown]
# ### 10. Color the text
#
# <font color=red> The text color is Red. </font> <br>
# <font color=blue> The text color is Blue. </font><br>
# <font color=green> The text color is Green. </font> <br>
# <font color=pink> The text color is Pink. </font><br>
# <font color=yellow> The text color is Yellow. </font><br>
# <font color=orange> The text color is Orange. </font>

# %% [markdown]
# ### 11. Links
#
# [Go to Google](https://www.google.com)
#
#
# [Go to Onlinekhabar News](https://www.onlinekhabar.com)
