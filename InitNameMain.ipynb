# %% [markdown]
# ![image.png](attachment:323eeb89-6fec-49a0-bb6b-18079345ca15.png)

# %%
# my_module.py
# my_module.py
def greet(name):
    print(f"Hello, {name}!")

def main():
    name = "Bkn!!  from main function."
    greet(name)

if __name__ == "__main__":
    main()
# Out:
# Hello, Bkn!!  from main function.!

# %%
# another_script.py
import my_module

# Calling the greet function from my_module
my_module.greet("Hari!! from another script")

# Since my_module.py is imported, the main() in my_module.py will not be executed
# Out:
# Hello, Hari!! from another script!
